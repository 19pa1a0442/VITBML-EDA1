# %% [markdown]
# <a href="https://colab.research.google.com/github/19pa1a0442/VITBML-EDA1/blob/master/ai_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## **Reading data**

# %%
u=pd.read_csv("/content/CompleteDataset.csv")
u
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Unnamed: 0               Name  Age  ...    RW   RWB    ST
# 0               0  Cristiano Ronaldo   32  ...  91.0  66.0  92.0
# 1               1           L. Messi   30  ...  91.0  62.0  88.0
# 2               2             Neymar   25  ...  89.0  64.0  84.0
# 3               3          L. Suárez   30  ...  87.0  68.0  88.0
# 4               4           M. Neuer   31  ...   NaN   NaN   NaN
# ...           ...                ...  ...  ...   ...   ...   ...
# 17976       17976          A. Kelsey   17  ...   NaN   NaN   NaN
# 17977       17977      B. Richardson   47  ...   NaN   NaN   NaN
# 17978       17978           J. Young   17  ...  44.0  32.0  45.0
# 17979       17979       J. Lundstram   18  ...  44.0  46.0  41.0
# ...

# %% [markdown]
# **INFORMATION** **ABOUT** **EVERY** **COLUMN**

# %% [markdown]
# **Name**:It indicates the name of the football player
#
# **Age**:It indicates the age of the player
#
# **Photo**:It gives the images of the players
#
# **Nationality**:It describes about the country of the players
#
# **Flag**:It shows the flag of the nation
#
# **Potential**:It is the incentive of all the players to change their strategy
#
# **club**:It is the overall organization as in Manchensar United football club(MUFC)
#
# **Club** **Logo**:It indicates symbol of the club
#
# **value**:Football players performance & market value
#
# **Wage**:salary paid to players
#
# **Accelaration**:It is the name that is given to any process  where the speed and direction of the object changes
#
# **Ball** **Control**:An offensive strategy in which a team tries to keep possession of the ballfor entended period of time
#
# **Balance**:Balance is an even distribution of weight enabling someone or something.
#
# **Composure**:How calm and stable you are under pressure
#
# **Agility**:Ability to change the direction of body
#
# **GK** **diving**:To stop soccer shots as quickly as possible  he should dive rather than running.
#
# **Crossing**:A cross is a medium to long range pass from a wide area of the field towards the centre of field.
#
# **Curve**:Try to hit low down on the right or left side.
#
# **Dribbing**:Dribble means travelling with the ball.
#
# **FK** **accuracy**:An indirect kick must be touched by another player.
#
# **Finishing**:One touch goal from a cross outside the corner of 18 yard box.
#
# **Heading** **Accuracy**:Technique used in association football control.
#
# **Interceptions**:Move in football happens when a player on the defensive team catches a ball.
#
# **Jumping**:A pass in which a player leaps into air and throws the ball to a teammate.
#
# **Long** **Passing**:Attempt to move ball to the longer distance.
#
# **Short** **Passing**:Attempt to move the ball to the shortest distances.
#
# **Shot** **Power**:The most common way  for  goals to be scored.
#
# **Siliding** **Tackle**:Push the ball away from opposite layer.
#
# **Sprint** **Speed**:Is a statcase metric that aims to more precilly quantify speed.
#
# **Stamina**:The ability to sustain.
#
# **Standing Tackle**:One where you remain on your feet.
#
# **Strength**: The maximal force that a muscle group can generate.
#
# **Vision**:The ability to find spaces during open plays.
#
# **Volleys**:Air borne strike in association with football.
#
# **Reaction**:Time taken for a player to react to a given situation.
#
# **GK positioning**:To prevent opposite team from getting the ball.
#
# **GK Reflexes**:To prevent the opposite team from scoring.
#
# **GK Kicking**:A goal is no longer required to leave the penalty area before a teammate touches ball for the kick.
#
#
#
#
#
#
#
#
#
#
#
#
# ---

# %% [markdown]
# # C**hecking data dimensions**

# %%
print(u.shape)
# Out:
# (17981, 75)

# %% [markdown]
# # Data Inspection

# %%
print(u.head(3))
# Out:
#    Unnamed: 0               Name  Age  ...    RW   RWB    ST
# 0           0  Cristiano Ronaldo   32  ...  91.0  66.0  92.0
# 1           1           L. Messi   30  ...  91.0  62.0  88.0
# 2           2             Neymar   25  ...  89.0  64.0  84.0
#
# [3 rows x 75 columns]

# %%
print(u.tail(4))
# Out:
#        Unnamed: 0           Name  Age  ...    RW   RWB    ST
# 17977       17977  B. Richardson   47  ...   NaN   NaN   NaN
# 17978       17978       J. Young   17  ...  44.0  32.0  45.0
# 17979       17979   J. Lundstram   18  ...  44.0  46.0  41.0
# 17980       17980      L. Sackey   18  ...  29.0  38.0  31.0
#
# [4 rows x 75 columns]

# %%
print(u.columns)
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
#        'GK positioning', 'GK reflexes', 'Heading accuracy', 'Interceptions',
#        'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
#        'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID',
#        'LAM', 'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB',
#        'Preferred Positions', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM',
#        'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
print(u.dtypes)
# Out:
# Unnamed: 0       int64
# Name            object
# Age              int64
# Photo           object
# Nationality     object
#                 ...
# RM             float64
# RS             float64
# RW             float64
# RWB            float64
# ST             float64
# Length: 75, dtype: object

# %% [markdown]
# # **Dropping** **columns**

# %%
u.drop(['Nationality'],axis=1,inplace=True)
u.head(3)
# Out:
#    Unnamed: 0               Name  Age  ...    RW   RWB    ST
# 0           0  Cristiano Ronaldo   32  ...  91.0  66.0  92.0
# 1           1           L. Messi   30  ...  91.0  62.0  88.0
# 2           2             Neymar   25  ...  89.0  64.0  84.0
#
# [3 rows x 74 columns]

# %% [markdown]
# # **Frequency** **distribution**

# %%
u['Age'].value_counts()
# Out:
# 25    1522
# 23    1394
# 24    1334
# 22    1324
# 21    1286
# 20    1245
# 26    1202
# 27    1152
# 29    1121
# 19    1069
# 28    1051
# 30     804
# 18     672
# 31     671
# 33     617
# 32     506
# 34     272
# 17     258
# 35     191
# 36     136
# 37      69
# 38      36
# 39      20
# 16      13
# 40       8
# 41       3
# 43       2
# 44       2
# 47       1
# Name: Age, dtype: int64

# %% [markdown]
# # loc (to subset **data** by Row/Column labels)

# %%
subset2=u.loc[[0,1,2],['Strength','Stamina']]
subset2.head(3)
# Out:
#   Strength Stamina
# 0       80      92
# 1       59      73
# 2       53      78

# %% [markdown]
# # **Statistics**

# %%
u.mean()
# Out:
# Unnamed: 0      8990.000000
# Age               25.144541
# Overall           66.247984
# Potential         71.190813
# Special         1594.095100
# CAM               59.251755
# CB                55.550464
# CDM               56.865283
# CF                59.030028
# CM                58.506833
# ID            207658.710138
# LAM               59.251755
# LB                56.979689
# LCB               55.550464
# LCM               58.506833
# LDM               56.865283
# LF                59.030028
# LM                60.057736
# LS                58.204050
# LW                59.359265
# LWB               57.698721
# RAM               59.251755
# RB                56.979689
# RCB               55.550464
# RCM               58.506833
# RDM               56.865283
# RF                59.030028
# RM                60.057736
# RS                58.204050
# RW                59.359265
# RWB               57.698721
# ST                58.204050
# dtype: float64

# %%
u.median()
# Out:
# Unnamed: 0      8990.0
# Age               25.0
# Overall           66.0
# Potential         71.0
# Special         1633.0
# CAM               60.0
# CB                57.0
# CDM               58.0
# CF                60.0
# CM                59.0
# ID            214057.0
# LAM               60.0
# LB                58.0
# LCB               57.0
# LCM               59.0
# LDM               58.0
# LF                60.0
# LM                61.0
# LS                59.0
# LW                60.0
# LWB               58.0
# RAM               60.0
# RB                58.0
# RCB               57.0
# RCM               59.0
# RDM               58.0
# RF                60.0
# RM                61.0
# RS                59.0
# RW                60.0
# RWB               58.0
# ST                59.0
# dtype: float64

# %%
u.mode()
# Out:
#        Unnamed: 0          Name   Age  ...    RW   RWB    ST
# 0               0  J. Rodríguez  25.0  ...  64.0  58.0  61.0
# 1               1   J. Valencia   NaN  ...   NaN   NaN   NaN
# 2               2   J. Williams   NaN  ...   NaN   NaN   NaN
# 3               3           NaN   NaN  ...   NaN   NaN   NaN
# 4               4           NaN   NaN  ...   NaN   NaN   NaN
# ...           ...           ...   ...  ...   ...   ...   ...
# 17976       17976           NaN   NaN  ...   NaN   NaN   NaN
# 17977       17977           NaN   NaN  ...   NaN   NaN   NaN
# 17978       17978           NaN   NaN  ...   NaN   NaN   NaN
# 17979       17979           NaN   NaN  ...   NaN   NaN   NaN
# 17980       17980           NaN   NaN  ...   NaN   NaN   NaN
#
# [17981 rows x 74 columns]

# %% [markdown]
# # **Histograms**

# %%
u.plot(x="Club",y="Potential",kind="hist")

# %%
u.plot(x="Age",y="Potential",kind="box")

# %%
u.plot(x="Age",y="Potential",kind="scatter")

# %%
u.plot(x="Age",y="Potential",kind="bar")

# %% [markdown]
# **FRAMING QUESTIONS**

# %% [markdown]
# 1.How to find the maximum of the dataset?

# %%
u.max()
# Out:
# Unnamed: 0                                            17980
# Name                                          Óscar Whalley
# Age                                                      47
# Photo         https://cdn.sofifa.org/48/18/players/9833.png
# Flag                    https://cdn.sofifa.org/flags/99.png
#                                   ...
# RM                                                       90
# RS                                                       92
# RW                                                       91
# RWB                                                      84
# ST                                                       92
# Length: 71, dtype: object

# %% [markdown]
# 2.How to count the unique datatypes?

# %%
u.get_dtype_counts()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   """Entry point for launching an IPython kernel.
# int64       6
# object     42
# float64    26
# dtype: int64

# %% [markdown]
# 3.How to select data based on datatypes?

# %%
u.select_dtypes(exclude=[object])
# Out:
#        Unnamed: 0  Age  Overall  Potential  ...    RS    RW   RWB    ST
# 0               0   32       94         94  ...  92.0  91.0  66.0  92.0
# 1               1   30       93         93  ...  88.0  91.0  62.0  88.0
# 2               2   25       92         94  ...  84.0  89.0  64.0  84.0
# 3               3   30       92         92  ...  88.0  87.0  68.0  88.0
# 4               4   31       92         92  ...   NaN   NaN   NaN   NaN
# ...           ...  ...      ...        ...  ...   ...   ...   ...   ...
# 17976       17976   17       46         63  ...   NaN   NaN   NaN   NaN
# 17977       17977   47       46         46  ...   NaN   NaN   NaN   NaN
# 17978       17978   17       46         61  ...  45.0  44.0  32.0  45.0
# 17979       17979   18       46         64  ...  41.0  44.0  46.0  41.0
# 17980       17980   18       46         64  ...  31.0  29.0  38.0  31.0
#
# [17981 rows x 32 columns]

# %% [markdown]
# 4.How to concise summary of a dataframe?

# %%
u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 74 columns):
# Unnamed: 0             17981 non-null int64
# Name                   17981 non-null object
# Age                    17981 non-null int64
# Photo                  17981 non-null object
# Flag                   17981 non-null object
# Overall                17981 non-null int64
# Potential              17981 non-null int64
# Club                   17733 non-null object
# Club Logo              17981 non-null object
# Value                  17981 non-null object
# Wage                   17981 non-null object
# Special                17981 non-null int64
# Acceleration           17981 non-null object
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# Composure              17981 non-null object
# ...

# %% [markdown]
# 5.How to describe the elements of file?

# %%
u.describe()
# Out:
#          Unnamed: 0           Age  ...           RWB            ST
# count  17981.000000  17981.000000  ...  15952.000000  15952.000000
# mean    8990.000000     25.144541  ...     57.698721     58.204050
# std     5190.811931      4.614272  ...      9.142825      9.181392
# min        0.000000     16.000000  ...     31.000000     31.000000
# 25%     4495.000000     21.000000  ...     51.000000     52.000000
# 50%     8990.000000     25.000000  ...     58.000000     59.000000
# 75%    13485.000000     28.000000  ...     64.000000     65.000000
# max    17980.000000     47.000000  ...     84.000000     92.000000
#
# [8 rows x 32 columns]

# %%
u["CAM"].fillna('89')
u
# Out:
#        Unnamed: 0               Name  Age  ...    RW   RWB    ST
# 0               0  Cristiano Ronaldo   32  ...  91.0  66.0  92.0
# 1               1           L. Messi   30  ...  91.0  62.0  88.0
# 2               2             Neymar   25  ...  89.0  64.0  84.0
# 3               3          L. Suárez   30  ...  87.0  68.0  88.0
# 4               4           M. Neuer   31  ...   NaN   NaN   NaN
# ...           ...                ...  ...  ...   ...   ...   ...
# 17976       17976          A. Kelsey   17  ...   NaN   NaN   NaN
# 17977       17977      B. Richardson   47  ...   NaN   NaN   NaN
# 17978       17978           J. Young   17  ...  44.0  32.0  45.0
# 17979       17979       J. Lundstram   18  ...  44.0  46.0  41.0
# 17980       17980          L. Sackey   18  ...  29.0  38.0  31.0
#
# [17981 rows x 74 columns]

# %%
u["CDM"].fillna('54')
# Out:
# 0        62
# 1        59
# 2        59
# 3        65
# 4        54
#          ..
# 17976    54
# 17977    54
# 17978    29
# 17979    47
# 17980    38
# Name: CDM, Length: 17981, dtype: object

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# We have learned how to use the pandas.we got an experience of working in teams.This helped us to enhance our knowledge.we even learnt of how to do a project.

# %% [markdown]
# Our team name is **GSOCSL**
#
# Our team members are:
#
# 1.G.Sowmya
#
#
# 2.G.Lavanya
#
#
# 3.G.Charishma Radhika
#
# 4.B.Rishika
